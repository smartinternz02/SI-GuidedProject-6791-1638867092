# %%
pow(7,4)
# Out:
# 2401

# %%
s="Hi there sam!"
s.split()
# Out:
# ['Hi', 'there', 'sam!']

# %%
planet="Earth"
diameter=12742
print("The diameter of {} is {} kilometers".format(planet,diameter))
# Out:
# The diameter of Earth is 12742 kilometers

# %%
lst = [1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]
lst[3][1][2]
# Out:
# ['hello']

# %%
 d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}
print(d['k1'][3]['tricky'][3]['target'][3])
# Out:
# hello

# %%
#Tuple:
    1. tuples are denoted by ()
    2.it is group of disimilar elements
    3. it is immutable
# List
    1.it is mutable or changable
    2.Each element in the list is called as item
    3. it is denoted by []

# %%
def Domain(email):
     print("Your Domain is",email.split('@')[-1])
email=input("please enter your mail id: ")
Domain(email)
# Out:
# please enter your mail id:  navi@gmail.com
# Your Domain is gmail.com

# %%
st=input("please enter your string: ")
def Find(st):
    if'dog' in st.lower():
        print("True")
    elif'DOG' in st.upper():
        print('True')
    else:
        print('False')
Find(st)
# Out:
# please enter your string:  Dog
# True

# %%
seq = ['soup','dog','salad','cat','great']
list(filter(lambda word: word[0]!='s',seq))
# Out:
# ['dog', 'cat', 'great']

# %%
def speed(s):
    if(s<=60):
        print("No Ticket")
    elif(s>=60 and s<=81):
        print("Small Ticket")
    else:
        print("Big Ticket")
sp=int(input("Enter Your Speed"))
bi=input("Is Your Birth Day or Not")
if(bi=='yes'):
    speed(sp-5)
else:
    speed(sp)
# Out:
# Enter Your Speed 85
# Is Your Birth Day or Not no
# Big Ticket
